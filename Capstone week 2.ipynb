# %% [markdown]
# __Import Libraries__

# %%
import requests 
import pandas as pd 
import numpy as np 
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim 
# !conda install -c conda-forge folium=0.5.0 --yes
import folium 
from IPython.display import Image 
from IPython.core.display import HTML 
from pandas.io.json import json_normalize
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/DSX-Python35
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     ca-certificates-2019.3.9   |       hecc5488_0         146 KB  conda-forge
#     certifi-2018.8.24          |        py35_1001         139 KB  conda-forge
#     openssl-1.0.2r             |       h14c3975_0         3.1 MB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.49-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# ...

# %% [markdown]
# __Define Foursquare Cedentials__

# %%
CLIENT_ID = '5NGYE0IFJ4TGFCS4F53PFXVRCA3FXEISEEYL4L0L3HX1I0QA' 
CLIENT_SECRET = 'AOAOWWGGT5H1D0KHVP3Z0N2X1FEQSRQGNAO5GFSYA1DUOUGH'
VERSION = '20190611'
LIMIT =30
print('Your credentails:')
print('Foursquare_ID: ' + CLIENT_ID)
print('Foursquare_Secret:' + CLIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: 5NGYE0IFJ4TGFCS4F53PFXVRCA3FXEISEEYL4L0L3HX1I0QA
# Foursquare_Secret:AOAOWWGGT5H1D0KHVP3Z0N2X1FEQSRQGNAO5GFSYA1DUOUGH

# %% [markdown]
# __Locate Area Coordinates__

# %%
city = 'Toronto'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.653963 -79.387207

# %% [markdown]
# __Define URL for Target Category__

# %%
search_query = 'Italian'
radius = 700
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=5NGYE0IFJ4TGFCS4F53PFXVRCA3FXEISEEYL4L0L3HX1I0QA&client_secret=AOAOWWGGT5H1D0KHVP3Z0N2X1FEQSRQGNAO5GFSYA1DUOUGH&ll=43.653963,-79.387207&v=20190611&query=Italian&radius=700&limit=30'

# %% [markdown]
# __Send get Request__

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d013db49fb6b72460e9aa42'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'primary': True,
#       'shortName': 'Italian'}],
#     'hasPerk': False,
#     'id': '52f6816f11d24a43115dc834',
#     'location': {'address': '382 Yonge St. Unit #7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Gerrard',
#      'distance': 652,
#      'formattedAddress': ['382 Yonge St. Unit #7 (Gerrard)',
#       'Toronto ON M5B 1S8',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.658920292028725,
#        'lng': -79.38289105381784}],
#      'lat': 43.658920292028725,
#      'lng': -79.38289105381784,
#      'postalCode': 'M5B 1S8',
# ...

# %% [markdown]
# __Put data into Dataframe__

# %%
venues = results['response']['venues']
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d110941735', 'shortName...    False
# 1  [{'id': '4bf58dd8d48988d110941735', 'shortName...    False
# 2  [{'id': '4bf58dd8d48988d110941735', 'shortName...    False
# 3  [{'id': '4bf58dd8d48988d12c951735', 'shortName...    False
# 4  [{'id': '4bf58dd8d48988d110941735', 'shortName...    False
#
#                          id             location.address location.cc  \
# 0  52f6816f11d24a43115dc834        382 Yonge St. Unit #7          CA
# 1  5b897e92db1d81002c91df8c           66 Wellington St W          CA
# 2  51bf3866498e55ee55df8db0                          NaN          CA
# 3  4bfc0289c3ba9521c00f9653              136 Beverley St          CA
# 4  526fe29411d2aeb3803013b0  109 McCaul Street, Unit #42          CA
#
#   location.city location.country location.crossStreet  location.distance  \
# 0       Toronto           Canada              Gerrard                652
# ...

# %% [markdown]
# __Clean up Dataframe/filter for category__

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                       name           categories  \
# 0         Scaddabush Italian Kitchen & Bar   Italian Restaurant
# 1                  Fabbrica Rustic Italian   Italian Restaurant
# 2                        The Fresh Italian   Italian Restaurant
# 3                Italian Consulate Toronto  Embassy / Consulate
# 4                 The Fresh Italian Eatery   Italian Restaurant
# 5                 Mustachio Italian Eatery   Italian Restaurant
# 6                       LA's Italian + Bar   Italian Restaurant
# 7                      john's italian cafe   Italian Restaurant
# 8   Classic italian style pizza food truck           Food Truck
# 9                         Little Anthony's   Italian Restaurant
# 10                                  Sbarro          Pizza Place
#
#                         address  cc     city country              crossStreet  \
# 0         382 Yonge St. Unit #7  CA  Toronto  Canada                  Gerrard
# ...

# %% [markdown]
# __Add Italian Venues to Map of Toronto__

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) 

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# __Check ratings of most central established Italian restaurants__

# %%
venue_id = '52f6816f11d24a43115dc834' # ID of Scaddabush Italian Kitchen & Bar
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 8.2

# %%
venue_id = '5b897e92db1d81002c91df8c' # ID of Fabrica Rustic Italian
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '51bf3866498e55ee55df8db0' # ID of The Fresh Italian
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '526fe29411d2aeb3803013b0' # ID of The Fresh Italian Eatery
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '573df789498e03dd8e54b166' # ID of Mustachio Italian Eatery
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '4f88cf84e4b002b90ab3b9b9' # ID of LA's Italian + Bar
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '53daae5b498e9c9597c19b23' # ID of John's Italian Cafe
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '4c787c9181bca0936180fa14' # ID of Classic Italian Style Pizza Food Truck
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '4b846dd4f964a520dc3431e3' # ID of Little Anthony's
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.0

# %%
venue_id = '4b4a2d09f964a520687d26e3' # ID of Sbarro
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 4.6
